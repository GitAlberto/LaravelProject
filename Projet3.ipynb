# %% [markdown]
# <a href="https://colab.research.google.com/github/GitAlberto/LaravelProject/blob/main/Projet3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importation des librairies

# %%
# Importation des librairies
# !pip install ydata-profiling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport # J'utilise pour le profilig
from google.colab import files
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.0/679.0 kB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.2 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=f30e0b10587b84930b17cb325e8124868ba03f47a1eddab895f8dacd441f094b
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
# ...

# %% [markdown]
# Importation du Dataset

# %%
# Importation du dataset
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b93e48ae-6431-49da-af13-ebf0afd0af09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b93e48ae-6431-49da-af13-ebf0afd0af09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Chargement du DataSet

# %%
df = pd.read_csv('Sample - Superstore.csv',delimiter=";",index_col=0, encoding='latin-1')

# %% [markdown]
# Copie du Dataset

# %%
# Copie du Dataset pour éviter tout dommage sur les données originales
df_copy = df.copy()

# %% [markdown]
# Observatios simples du dataset

# %%
#Affichage des 5 premiers enregistrements
df_copy.head()
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156  08/11/2016  11/11/2016    Second Class    CG-12520
# 2       CA-2016-152156  08/11/2016  11/11/2016    Second Class    CG-12520
# 3       CA-2016-138688  12/06/2016  16/06/2016    Second Class    DV-13045
# 4       US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
# 5       US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
#
#           Customer Name    Segment        Country             City  \
# Row ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#              State  Postal Code Region       Product ID         Category  \
# Row ID
# ...

# %%
# Affichage des 5 deniers enregistrements
df_copy.tail()
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 9990    CA-2014-110422  21/01/2014  23/01/2014    Second Class    TB-21400
# 9991    CA-2017-121258  26/02/2017  03/03/2017  Standard Class    DB-13060
# 9992    CA-2017-121258  26/02/2017  03/03/2017  Standard Class    DB-13060
# 9993    CA-2017-121258  26/02/2017  03/03/2017  Standard Class    DB-13060
# 9994    CA-2017-119914  04/05/2017  09/05/2017    Second Class    CC-12220
#
#            Customer Name   Segment        Country         City       State  \
# Row ID
# 9990    Tom Boeckenhauer  Consumer  United States        Miami     Florida
# 9991         Dave Brooks  Consumer  United States   Costa Mesa  California
# 9992         Dave Brooks  Consumer  United States   Costa Mesa  California
# 9993         Dave Brooks  Consumer  United States   Costa Mesa  California
# 9994        Chris Cortes  Consumer  United States  Westminster  California
#
# ...

# %% [markdown]
# Informations  générales du Dataset

# %%
# Informations générales du Dataset
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 1 to 9994
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9988 non-null   float64
# ...

# %% [markdown]
# Constats à ce niveau :
#
#
# *   Nombre de colonnes : 20
# *   Les colonnes de dates ne sont pas au bon format
# *   Colonnes numériques : 4 (Sales,Quantity,Discount,Profit)
# *   Colonnes de Dates : 2 (Order Date & Ship Date) - Pas encore au bon format
# *   Colonnes Objets : les 14 autres (Postal Code) au mauvais format
# *   6 valeurs  manquantes sur chacune des 4 colonnes numériques

# %% [markdown]
# Obervarion des valeurs manquantes

# %%
# Comptage du nombre de valeurs manquantes de chaque colonne
df_copy.isna().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            6
# Quantity         6
# Discount         6
# Profit           6
# dtype: int64

# %%
# Pourcentage des valeurs manquantes pour determiner le traitement à appliquer sur celles-ci
Pourcentage_NaN = df_copy.isna().sum().sum() / len(df_copy) * 100
print("=|===============================================================|=")
print("=|===============================================================|=")
print("   Le pourcentage de valeur manquantes du dataset est de : ",Pourcentage_NaN)
print("                    Peut être arrondi à ~ :",np.round(Pourcentage_NaN))
print("=|===============================================================|=")
print("=|===============================================================|=")
# Out:
# =|===============================================================|=
# =|===============================================================|=
#    Le pourcentage de valeur manquantes du dataset est de :  0.24014408645187113
#                     Peut être arrondi à ~ : 0.0
# =|===============================================================|=
# =|===============================================================|=

# %% [markdown]
# De par les observations précédentes, notemment celle du % des valeurs manquantes, nous pouvons proceder à l'imputation par suppression des lignes qui les contiennent

# %%
# Suppression des valeurs manquantes et reinitialisation des index
df_copy = df_copy.dropna().reset_index(drop=True)
# Reverifiaction des valeurs manquantes
df_copy.isna().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# Analyse de la granularité du dataset

# %%
# Obervation de la granularité du dataset
df_copy['Order ID'].value_counts().head(10)
# Out:
# Order ID
# CA-2017-100111    14
# CA-2017-157987    12
# CA-2016-165330    11
# US-2016-108504    11
# CA-2016-105732    10
# US-2015-126977    10
# CA-2015-131338    10
# US-2016-114013     9
# CA-2017-140949     9
# CA-2015-132626     9
# Name: count, dtype: int64

# %% [markdown]
# D'après l'obervation précédente : les commandes du dataset sont étallées sur plusieurs lignes.
# * Par exemple, la commande CA-2017-100111 étallée sur	14 lignes du dataset.
# * Une ligne correspond à un produit d'une commande

# %%
# Nombre de commandes étallées sur plusieurs lignes
print("=|=============================================================================|=")
print("=|=============================================================================|=")
print("   Les commandes qui sétallent sur plusieurs lignes sont au nombre de : ",(df['Order ID'].value_counts() > 1).sum())
print("=|=============================================================================|=")
print("=|=============================================================================|=")
# Out:
# =|=============================================================================|=
# =|=============================================================================|=
#    Les commandes qui sétallent sur plusieurs lignes sont au nombre de :  2471
# =|=============================================================================|=
# =|=============================================================================|=

# %% [markdown]
# Etant donné que les commandes sont étallées sur plusieurs lignes , il est nécéssaire de faires des agrégation groupées pour refléter la réalité en prenant chaque commande dans sa globalité !

# %%
# Total de ventes
Ventes_total = df_copy.groupby('Order ID').agg({'Sales': 'sum'}).sum()
print("=|=======================================|=")
print("=|=======================================|=")
print("  Masse total de ventes : ", "{:,.2f}".format(Ventes_total['Sales']),"€")
print("=|=======================================|=")
print("=|=======================================|=")
# Out:
# =|=======================================|=
# =|=======================================|=
#   Masse total de ventes :  2,295,273.92 €
# =|=======================================|=
# =|=======================================|=

# %%
# Moyenne de ventes
Ventes_moyenne = df_copy.groupby('Order ID').agg({'Sales': 'sum'}).mean()
print("=|=======================================|=")
print("=|=======================================|=")
print("     Masse total de ventes : ", "{:,.2f}".format(Ventes_moyenne['Sales']),"€")
print("=|=======================================|=")
print("=|=======================================|=")
# Out:
# =|=======================================|=
# =|=======================================|=
#      Masse total de ventes :  458.32 €
# =|=======================================|=
# =|=======================================|=

# %%
# Total de profit
Profit_total = df_copy.groupby('Order ID').agg({'Profit': 'sum'}).sum()
print("=|=======================================|=")
print("=|=======================================|=")
print("   Masse total de profit : ", "{:,.2f}".format(Profit_total['Profit']),"€")
print("=|=======================================|=")
print("=|=======================================|=")
# Out:
# =|=======================================|=
# =|=======================================|=
#    Masse total de profit :  285,988.28 €
# =|=======================================|=
# =|=======================================|=

# %%
# Moyenne de profit
Profit_moyenne = df_copy.groupby('Order ID').agg({'Profit': 'sum'}).mean()
print("=|=======================================|=")
print("=|=======================================|=")
print("          Profit moyen : ", "{:,.2f}".format(Profit_moyenne['Profit']),"€")
print("=|=======================================|=")
print("=|=======================================|=")
# Out:
# =|=======================================|=
# =|=======================================|=
#           Profit moyen :  57.11 €
# =|=======================================|=
# =|=======================================|=

# %%
# Résumé statistique
df_copy.describe()
# Out:
#                        Order Date                      Ship Date  \
# count                        9988                           9988
# mean   2016-04-30 01:07:02.426912  2016-05-04 00:06:03.315979264
# min           2014-01-03 00:00:00            2014-01-07 00:00:00
# 25%           2015-05-23 00:00:00            2015-05-27 00:00:00
# 50%           2016-06-26 00:00:00            2016-06-29 00:00:00
# 75%           2017-05-14 00:00:00            2017-05-18 00:00:00
# max           2017-12-30 00:00:00            2018-01-05 00:00:00
# std                           NaN                            NaN
#
#               Sales     Quantity     Discount       Profit
# count   9988.000000  9988.000000  9988.000000  9988.000000
# mean     229.803156     3.788646     0.156196    28.633188
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.248000     2.000000     0.000000     1.727550
# 50%       54.376000     3.000000     0.200000     8.641350
# ...

# %% [markdown]
# Retypage des colonnes au bon format

# %%
# Retypage des colonnes de dates au bon format
df_copy['Order Date'] = pd.to_datetime(df_copy['Order Date'], format='%d/%m/%Y')
df_copy['Ship Date'] = pd.to_datetime(df_copy['Ship Date'], format='%d/%m/%Y')

# %%
# Retypage de la colonne Postal Code en Object
df_copy['Postal Code'] = df_copy['Postal Code'].astype(str)

# %% [markdown]
# Analyse des types de colonnes

# %%
#Affichage de la liste des colonnes
df_copy.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# Toutes les colonnes (variables) catégorielles sont de types :
# * NOMINALES, ce qui implique aucun ordre entre elles.

# %% [markdown]
# Les colonnes quantitatives sont présentes sous 2 formes :
# *   variables continues : Sales, Discount, Profit
# *   variables discrètes : Quantity

# %% [markdown]
# Les colonnes temporelles sont au nombre de 2 :
# * Order Date
# * Shipe Date

# %% [markdown]
# Découpage du Dataset en 3 parties :
# * df_copy_categs (variables catégorielles)
# * df_copy_nums (variables numériques)
# * df_copy_dates (variables temporelles)

# %%
# df_copy_dates
df_copy_dates = df_copy[['Order Date','Ship Date']]
# Affichage de df_copy_dates
df_copy_dates.head()
# Out:
#   Order Date  Ship Date
# 0 2016-11-08 2016-11-11
# 1 2016-11-08 2016-11-11
# 2 2016-06-12 2016-06-16
# 3 2015-10-11 2015-10-18
# 4 2015-10-11 2015-10-18

# %%
# df_copy_nums
df_copy_nums = df_copy[['Sales','Quantity','Discount','Profit']]
# Affichage de df_copy_nums
df_copy_nums.head()
# Out:
#       Sales  Quantity  Discount    Profit
# 0  261.9600       2.0      0.00   41.9136
# 1  731.9400       3.0      0.00  219.5820
# 2   14.6200       2.0      0.00    6.8714
# 3  957.5775       5.0      0.45 -383.0310
# 4   22.3680       2.0      0.20    2.5164

# %%
# df_copy_categs
df_copy_categs = df_copy[[
    'Order ID',
    'Ship Mode',
    'Customer ID',
    'Customer Name',
    'Segment',
    'Country',
    'City',
    'State',
    'Postal Code',
    'Region',
    'Product ID',
    'Category',
    'Sub-Category',
    'Product Name']]
df_copy_categs.head()
# Out:
#          Order ID       Ship Mode Customer ID    Customer Name    Segment  \
# 0  CA-2016-152156    Second Class    CG-12520      Claire Gute   Consumer
# 1  CA-2016-152156    Second Class    CG-12520      Claire Gute   Consumer
# 2  CA-2016-138688    Second Class    DV-13045  Darrin Van Huff  Corporate
# 3  US-2015-108966  Standard Class    SO-20335   Sean O'Donnell   Consumer
# 4  US-2015-108966  Standard Class    SO-20335   Sean O'Donnell   Consumer
#
#          Country             City       State Postal Code Region  \
# 0  United States        Henderson    Kentucky       42420  South
# 1  United States        Henderson    Kentucky       42420  South
# 2  United States      Los Angeles  California       90036   West
# 3  United States  Fort Lauderdale     Florida       33311  South
# 4  United States  Fort Lauderdale     Florida       33311  South
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %% [markdown]
# Analyse commerciale

# %% [markdown]
# Observation de valeurs abérrantes des colonnes numériques du datatset (s'il y en a)

# %%
# Creation de la fonction pour observer les valeurs aberantes
def obs_outliers(data,column):
  Q1 = data[column].quantile(0.25)
  Q3 = data[column].quantile(0.75)

  # Difference interquartile
  IQR = Q3 - Q1

  # Definition des bornes
  borne_inf = Q1 - 1.5 * IQR
  borne_sup = Q3 + 1.5 * IQR

  # Recuperation de ces valeurs dans une liste
  liste_outliers = data[(data[column] < borne_inf) | (data[column] > borne_sup)][column].tolist()
  return liste_outliers

# %% [markdown]
# Modélisation d'un mini dataset qui groupe les commandes en une seule ligne

# %%
# Creation d'un mini dataset pour grouper les commandes
mini_df_orders_groupés = df_copy.groupby('Order ID').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum'
}).reset_index()

# %% [markdown]
# Tableau de resumé de chaque colonne

# %%
# Visu Outliers Sales
print("=|=========================================|=")
print("=|=========================================|=")
print("          Nombre de commandes : ",mini_df_orders_groupés["Order ID"].nunique())
print("=|=========================================|=")
print("=|=========================================|=")
print("            Nombre outliers : ",len(obs_outliers(mini_df_orders_groupés,'Sales')))
print("=|=========================================|=")
print("=|=========================================|=")
print("         Max des ventes : ", mini_df_orders_groupés['Sales'].max(),"€")
print("=|=========================================|=")
print("=|=========================================|=")
print("           Min des ventes : ", mini_df_orders_groupés['Sales'].min(),"€")
print("=|=========================================|=")
print("=|=========================================|=")
print("          Med des ventes : ", mini_df_orders_groupés['Sales'].median(),"€")
print("=|=========================================|=")
print("=|=========================================|=")
print("           Moy des ventes : ", mini_df_orders_groupés['Sales'].mean().round(2),"€")
print("=|=========================================|=")
print("=|=========================================|=")
print("         ecartype  ventes : ", round(mini_df_orders_groupés['Sales'].std(),2),"€")
print("=|=========================================|=")
print("=|=========================================|=")
# Out:
# =|=========================================|=
# =|=========================================|=
#           Nombre de commandes :  5008
# =|=========================================|=
# =|=========================================|=
#             Nombre outliers :  459
# =|=========================================|=
# =|=========================================|=
#          Max des ventes :  23661.228 €
# =|=========================================|=
# =|=========================================|=
#            Min des ventes :  0.556 €
# =|=========================================|=
# =|=========================================|=
#           Med des ventes :  151.875 €
# =|=========================================|=
# =|=========================================|=
#            Moy des ventes :  458.32 €
# =|=========================================|=
# =|=========================================|=
#          ecartype  ventes :  954.86 €
# =|=========================================|=
# ...

# %%
sns.boxplot(data=mini_df_orders_groupés, y='Sales')
plt.title("Distribution des ventes par commande")
plt.ylabel("Montant des ventes (€)")
plt.show()

# %%
# Visu Outliers profit
print("=|=========================================|=")
print("=|=========================================|=")
print("         Nombre de commandes : ",mini_df_orders_groupés["Order ID"].nunique())
print("=|=========================================|=")
print("=|=========================================|=")
print("           Nombre outliers : ",len(obs_outliers(mini_df_orders_groupés,'Profit')))
print("=|=========================================|=")
print("=|=========================================|=")
print("        Max des profits : ", mini_df_orders_groupés['Profit'].max(),"€")
print("=|=========================================|=")
print("=|=========================================|=")
print("        Min des profits : ", mini_df_orders_groupés['Profit'].min(),"€")
print("=|=========================================|=")
print("=|=========================================|=")
print("           Med des profits : ", round(mini_df_orders_groupés['Profit'].median()),"€")
print("=|=========================================|=")
print("=|=========================================|=")
print("          Moy des profits : ", mini_df_orders_groupés['Profit'].mean().round(2),"€")
print("=|=========================================|=")
print("=|=========================================|=")
print("         ecartype  profits : ", round(mini_df_orders_groupés['Profit'].std(),2),"€")
print("=|=========================================|=")
print("=|=========================================|=")
# Out:
# =|=========================================|=
# =|=========================================|=
#          Nombre de commandes :  5008
# =|=========================================|=
# =|=========================================|=
#            Nombre outliers :  869
# =|=========================================|=
# =|=========================================|=
#         Max des profits :  8762.3891 €
# =|=========================================|=
# =|=========================================|=
#         Min des profits :  -6892.3748 €
# =|=========================================|=
# =|=========================================|=
#            Med des profits :  16 €
# =|=========================================|=
# =|=========================================|=
#           Moy des profits :  57.11 €
# =|=========================================|=
# =|=========================================|=
#          ecartype  profits :  344.98 €
# =|=========================================|=
# ...

# %%
sns.boxplot(data=mini_df_orders_groupés, y='Profit')
plt.title("Distribution des profits par commande")
plt.ylabel("Montant des ventes (€)")
plt.show()

# %%
# Visu outliers Discount
print("=|=========================================|=")
print("=|=========================================|=")
print("          Nombre de commandes : ",mini_df_orders_groupés["Order ID"].nunique())
print("=|=========================================|=")
print("=|=========================================|=")
print("            Nombre outliers : ",len(obs_outliers(df_copy_nums,'Discount')))
print("=|=========================================|=")
print("=|=========================================|=")
print("        Maximun des discounts : ", df_copy_nums['Discount'].max(),"%")
print("=|=========================================|=")
print("=|=========================================|=")
print("        Minimum des discounts : ", df_copy_nums['Discount'].min(),"%")
print("=|=========================================|=")
print("=|=========================================|=")
print("          Med des discounts : ", df_copy_nums['Discount'].median(),"%")
print("=|=========================================|=")
print("=|=========================================|=")
print("          Moy des discounts : ", df_copy_nums['Discount'].mean().round(1),"%")
print("=|=========================================|=")
print("=|=========================================|=")
print("         ecartype  discounts : ", round(df_copy_nums['Discount'].std(),2),"%")
print("=|=========================================|=")
print("=|=========================================|=")
# Out:
# =|=========================================|=
# =|=========================================|=
#           Nombre de commandes :  5008
# =|=========================================|=
# =|=========================================|=
#             Nombre outliers :  856
# =|=========================================|=
# =|=========================================|=
#         Maximun des discounts :  0.8 %
# =|=========================================|=
# =|=========================================|=
#         Minimum des discounts :  0.0 %
# =|=========================================|=
# =|=========================================|=
#           Med des discounts :  0.2 %
# =|=========================================|=
# =|=========================================|=
#           Moy des discounts :  0.2 %
# =|=========================================|=
# =|=========================================|=
#          ecartype  discounts :  0.21 %
# =|=========================================|=
# ...

# %%
sns.boxplot(data=df_copy_nums, y='Discount')
plt.title("Distribution des discount")
plt.ylabel("Montant des ventes (€)")
plt.show()

# %%
# Visu outliers Quantity
print("=|=========================================|=")
print("=|=========================================|=")
print("          Nombre de commandes : ",mini_df_orders_groupés["Order ID"].nunique())
print("=|=========================================|=")
print("=|=========================================|=")
print("             Nombre outliers : ",len(obs_outliers(mini_df_orders_groupés,'Quantity')))
print("=|=========================================|=")
print("=|=========================================|=")
print("         Maximun des Quantities : ", mini_df_orders_groupés['Quantity'].max())
print("=|=========================================|=")
print("=|=========================================|=")
print("         Maximun des Quantities : ", mini_df_orders_groupés['Quantity'].min())
print("=|=========================================|=")
print("=|=========================================|=")
print("          Med des Quantities : ", mini_df_orders_groupés['Quantity'].median())
print("=|=========================================|=")
print("=|=========================================|=")
print("          Moy des Quantities : ", mini_df_orders_groupés['Quantity'].mean().round(2))
print("=|=========================================|=")
print("=|=========================================|=")
print("         ecartype  Quantities : ", round(mini_df_orders_groupés['Quantity'].std(),2))
print("=|=========================================|=")
print("=|=========================================|=")
# Out:
# =|=========================================|=
# =|=========================================|=
#           Nombre de commandes :  5008
# =|=========================================|=
# =|=========================================|=
#              Nombre outliers :  235
# =|=========================================|=
# =|=========================================|=
#          Maximun des Quantities :  52.0
# =|=========================================|=
# =|=========================================|=
#          Maximun des Quantities :  1.0
# =|=========================================|=
# =|=========================================|=
#           Med des Quantities :  6.0
# =|=========================================|=
# =|=========================================|=
#           Moy des Quantities :  7.56
# =|=========================================|=
# =|=========================================|=
#          ecartype  Quantities :  6.22
# =|=========================================|=
# ...

# %%
sns.boxplot(data=mini_df_orders_groupés, y='Quantity')
plt.title("Distribution des Quantities")
plt.ylabel("Montant des ventes (€)")
plt.show()

# %% [markdown]
# Analyse univariée sur catégories

# %%
# Pour la variable Category
df_copy_categs['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1841
# Name: count, dtype: int64

# %% [markdown]
# Creation du graphique à barres pour le nombre de commandes par catégories

# %%
# Compter les valeurs
counts = df_copy_categs['Category'].value_counts().reset_index()
counts.columns = ['Category', 'Count']

# Initialisation du plot
plt.figure(figsize=(8, 5))
plot = sns.barplot(data=counts, x='Category', y='Count', palette='viridis')

# Ajouter les annotations (valeurs au-dessus des barres)
for index, row in counts.iterrows():
    plot.text(x=index,
              y=row['Count'] + 1,
              s=row['Count'],
              ha='center',
              va='bottom')

# Personnalisation
plt.title('Distribution des Catégories')
plt.xlabel('Catégories')
plt.ylabel('Nombre d\'éléments')
plt.xticks(rotation=45)

# Affichage propre
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-35-91274440.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.barplot(data=counts, x='Category', y='Count', palette='viridis')

# %%
# La variable sub_category
df_copy_categs['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     769
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %% [markdown]
# Analyse univariée sur les sous-catégories

# %% [markdown]
# Creation du graphique à barres pour le nombre de commandes par sous-catégories

# %%
# Affichage d'un barplot
counts = df_copy_categs['Sub-Category'].value_counts().reset_index()
counts.columns = ['Sub-Category', 'Count']

#Initialisation du plot
plt.figure(figsize=(12, 6))
plot = sns.barplot(data=counts, x='Sub-Category', y='Count', palette='viridis')

# Boucle pour afficher les valreurs directement sur le graphique
for index, row in counts.iterrows():
  plot.text(x=index,
            y=row['Count'] + 1,
            s=row['Count'],
            ha='center',
            va='bottom')

#Personnalisation
plt.title('Distribution des Sous-Catégories')
plt.xlabel('Sous-Catégories')
plt.ylabel('Nombre d\'achats')
plt.xticks(rotation=45)


# Affichage propre
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-37-2437455754.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.barplot(data=counts, x='Sub-Category', y='Count', palette='viridis')

# %% [markdown]
# Analyse univariée sur villes

# %%
# Nombre de villes
df_copy_categs['City'].nunique()
# Out:
# 531

# %%
# Les 10 meilleurs villes
df_copy_categs.groupby('City').agg({'Order ID': 'count'}).sort_values(by='Order ID', ascending=False).head(10)
# Out:
#                Order ID
# City
# New York City       915
# Los Angeles         747
# Philadelphia        536
# San Francisco       510
# Seattle             428
# Houston             377
# Chicago             313
# Columbus            222
# San Diego           170
# Springfield         163

# %%
# Les 10 pires villes
df_copy_categs.groupby('City').agg({'Order ID': 'count'}).sort_values(by='Order ID', ascending=True).head(10)
# Out:
#                Order ID
# City
# Aberdeen              1
# Abilene               1
# Atlantic City         1
# Bartlett              1
# Baytown               1
# Tinley Park           1
# Waukesha              1
# Waterloo              1
# Billings              1
# Vacaville             1

# %%
# Clients par villes (City), les 15 meilleures villes
counts = df_copy_categs['City'].value_counts().head(15).reset_index()
counts.columns = ['City', 'Count']

#Initialisation du plot
plt.figure(figsize=(12, 6))
plot = sns.barplot(data=counts, x='City', y='Count', palette='viridis')

# Boucle pour afficher les valeurs
for index, row in counts.iterrows():
  plot.text(x=index,
            y=row['Count'] + 1,
            s=row['Count'],
            ha='center',
            va='bottom')

#Personnalisation
plt.title('Distribution des Villes')
plt.xlabel('Villes')
plt.ylabel('Nombre d\'achats')
plt.xticks(rotation=45)

# Affichage propre
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-41-2569140279.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.barplot(data=counts, x='City', y='Count', palette='viridis')

# %% [markdown]
# Gestion des pertes

# %%
# creation du dataframe des commandes à pertes
df_pertes = mini_df_orders_groupés[mini_df_orders_groupés['Profit'] < 0]
df_pertes.head()
# Out:
#           Order ID    Sales   Profit  Quantity
# 1   CA-2014-100090  699.192 -19.0890       9.0
# 15  CA-2014-101147    2.394  -6.3441       1.0
# 16  CA-2014-101175  100.704  -1.2588       6.0
# 24  CA-2014-101602  803.960 -30.9610       8.0
# 25  CA-2014-101770    1.869  -1.3083       1.0

# %%
# Nombre de commandes à pertes
print("Nombre de commandes à pertes : ",len(df_pertes))
# Out:
# Nombre de commandes à pertes :  1022

# %%
# %tage des pertes
pourcentage_pertes = len(df_pertes) / len(mini_df_orders_groupés) * 100
print("Le pourcentage de commandes à pertes est de : ",round(pourcentage_pertes,2),"%")
# Out:
# Le pourcentage de commandes à pertes est de :  20.41 %

# %%
# creation du dataframe de commandes à rentables
df_rentables = mini_df_orders_groupés[mini_df_orders_groupés['Profit'] > 0]
df_rentables.head()
# Out:
#          Order ID    Sales    Profit  Quantity
# 0  CA-2014-100006  377.970  109.6113       3.0
# 2  CA-2014-100293   91.056   31.8696       6.0
# 3  CA-2014-100328    3.928    1.3257       1.0
# 4  CA-2014-100363   21.376    7.7192       5.0
# 5  CA-2014-100391   14.620    6.7252       2.0

# %%
# nombre de commandes rentables
print("Nombre de commandes rentables : ",len(df_rentables))
# Out:
# Nombre de commandes rentables :  3969

# %%
# %tage de profits
pourcentage_rentables = len(df_rentables) / len(mini_df_orders_groupés) * 100
print("Le pourcentage de commandes rentables est de : ",pourcentage_rentables,"%")
# Out:
# Le pourcentage de commandes rentables est de :  79.25319488817891 %

# %% [markdown]
# Scatter plot, profit-discount

# %%
# Taille de la figure
plt.figure(figsize=(10, 6))

# Scatter plot avec Seaborn
sns.scatterplot(data=df_copy, x='Discount', y='Profit', color='purple', alpha=0.6)

# Ligne horizontale à y = 0 (pour repérer les pertes)
plt.axhline(0, color='red', linestyle='--', linewidth=1)

# Personnalisation du graphique
plt.title('scatter entre le Discount et le Profit')
plt.xlabel('Discount (Réduction)')
plt.ylabel('Profit (Bénéfice)')
plt.grid(True)
plt.tight_layout()

# Affichage
plt.show()

# %% [markdown]
# Nous remarquons clairement que plus la reduction augmente, plus le profit est bas, voire négatif. C'est ça qu'on doit éviter, plus rien n'est positif à partir de 45%

# %% [markdown]
# Régression linéaire

# %%
# Taille du graphique
plt.figure(figsize=(10, 6))

# Scatter plot avec la régression linéaire
sns.regplot(data=df_copy, x='Discount', y='Profit', scatter_kws={'alpha': 0.5}, line_kws={'color': 'red'})

# Ligne horizontale à y = 0 (zéro profit)
plt.axhline(0, color='gray', linestyle='--')

# Titres et axes
plt.title('Régression linéaire : Discount vs Profit')
plt.xlabel('Discount (Réduction)')
plt.ylabel('Profit (Bénéfice)')
plt.grid(True)
plt.tight_layout()

# Affichage
plt.show()

# %%
# Analyse de correlation entre profit et reduction
df_copy[['Profit', 'Discount']].corr()
# Out:
#            Profit  Discount
# Profit    1.00000  -0.21949
# Discount -0.21949   1.00000

# %% [markdown]
# Etant donné que l'indice de correlation entre ces deux variables : Profit et Discount est de -0.21949 alors ces deux variables ne sont pas corrélés.
#
# Selon nos observations , la meilleurs manière de vendre sans faire des pertes est de ne pas faire de promotions car, on le remarque les pertes commencent au moment où on fait des promotions
#
# Les produits à fort discount (>45%) génèrent en moyenne un profit négatif

# %%
# Heatmap
sns.heatmap(df[['Sales', 'Profit', 'Discount', 'Quantity']].corr(), annot=True, cmap='coolwarm')
plt.title('Matrice de corrélation')
plt.show()

# %%
# Les 10 meilleurs produits en profits
df_copy.groupby('Product ID').agg({'Profit': 'sum'}).sort_values(by='Profit', ascending=False).head(10)
# Out:
#                      Profit
# Product ID
# TEC-CO-10004722  25199.9280
# OFF-BI-10003527   7753.0390
# TEC-CO-10001449   6983.8836
# TEC-CO-10003763   4570.9347
# TEC-AC-10002049   4425.3432
# TEC-MA-10001127   4094.9766
# TEC-MA-10003979   3772.9461
# TEC-MA-10001047   3717.9714
# OFF-BI-10001120   3345.2823
# TEC-MA-10000045   3343.5360

# %%
# Les pires produits : qui génèrent les plus grosses pertes
df_copy.groupby('Product ID').agg({'Profit': 'sum'}).sort_values(by='Profit', ascending=True).head(10)
# Out:
#                     Profit
# Product ID
# TEC-MA-10000418 -8879.9704
# TEC-MA-10000822 -4589.9730
# TEC-MA-10004125 -3839.9904
# FUR-TA-10000198 -2876.1156
# FUR-TA-10001889 -1934.3976
# OFF-BI-10004995 -1878.1662
# TEC-MA-10002412 -1811.0784
# OFF-SU-10002881 -1299.1836
# FUR-TA-10001950 -1201.0581
# FUR-TA-10004289 -1148.4375

# %%
#Total de pertes par catégories
df_joint = df_pertes.merge(df_copy_categs[['Order ID', 'Category']], on='Order ID', how='left')
df_joint.groupby('Category').agg({'Profit': 'sum'}).sort_values(by='Profit', ascending=True)
# Out:
#                       Profit
# Category
# Office Supplies -218351.3478
# Furniture       -111575.7765
# Technology       -97146.1876

# %%
# Total des pertes par sous catégories
df_joint = df_pertes.merge(df_copy_categs[['Order ID', 'Sub-Category']], on='Order ID', how='left')
df_joint.groupby('Sub-Category').agg({'Profit': 'sum'}).sort_values(by='Profit', ascending=True)
# Out:
#                   Profit
# Sub-Category
# Binders      -96145.0005
# Furnishings  -38923.8879
# Accessories  -36250.7415
# Tables       -35457.3714
# Machines     -34262.9118
# Phones       -26632.5343
# Appliances   -26055.9120
# Paper        -25375.9721
# Art          -24420.1967
# Storage      -22945.6930
# Chairs       -22738.3068
# Bookcases    -14456.2104
# Fasteners     -7012.9063
# Supplies      -6755.2565
# Envelopes     -5456.6560
# Labels        -4183.7547

# %%
# Les 5 produits les plus achetés
df_copy.groupby('Product ID').agg({'Quantity': 'sum'}).sort_values(by='Quantity', ascending=False).head(5)
# Out:
#                  Quantity
# Product ID
# TEC-AC-10003832      75.0
# OFF-PA-10001970      70.0
# OFF-BI-10001524      67.0
# FUR-CH-10002647      64.0
# OFF-BI-10002026      64.0

# %%
# Les 5 produits les moins achetés
df_copy.groupby('Product ID').agg({'Quantity': 'sum'}).sort_values(by='Quantity', ascending=True).head(5)
# Out:
#                  Quantity
# Product ID
# FUR-CH-10002317       1.0
# OFF-AR-10002704       1.0
# TEC-MA-10003493       1.0
# OFF-PA-10000048       1.0
# FUR-BO-10002206       1.0

# %%
# Les 10 meilleurs clients en profit
df_copy.groupby('Customer ID').agg({'Profit': 'sum'}).sort_values(by='Profit', ascending=False).head(10)
# Out:
#                 Profit
# Customer ID
# TC-20980     8981.3239
# RB-19360     6976.0959
# SC-20095     5757.4119
# HL-15040     5622.4292
# AB-10105     5444.8055
# TA-21385     4703.7883
# CM-12385     3899.8904
# KD-16495     3038.6254
# AR-10540     2884.6208
# DR-12940     2869.0760

# %%
# Les 10 pires clients en profit
df_copy.groupby('Customer ID').agg({'Profit': 'sum'}).sort_values(by='Profit', ascending=True).head(10)
# Out:
#                 Profit
# Customer ID
# CS-12505    -6626.3895
# GT-14635    -4108.6589
# LF-17185    -3583.9770
# SR-20425    -3333.9144
# HG-14965    -2797.9635
# NC-18415    -2204.8072
# SB-20290    -2082.7451
# SM-20320    -1980.7393
# CP-12340    -1850.3029
# NF-18385    -1695.9714

# %% [markdown]
# # Analyse temporelle détaillée

# %%
# Chiffre d'affaires par ans
df_copy.groupby(df_copy['Order Date'].dt.year).agg({'Sales': 'sum'}).sort_values(by='Sales', ascending=False)
# Out:
#                   Sales
# Order Date
# 2017        732514.5512
# 2016        608504.8940
# 2014        483721.9701
# 2015        470532.5090

# %%
# Pie plot chiffre d'affaire par ans
df_copy.groupby(df_copy['Order Date'].dt.year).agg({'Sales': 'sum'}).sort_values(by='Sales', ascending=False).plot(kind='pie', y='Sales', autopct='%1.1f%%')
plt.title('Chiffre d\'affaires par ans')
plt.ylabel('')
plt.show()

# %%
# Chiffre d'affaire par mois et par ans
df_copy.groupby([df_copy['Order Date'].dt.year, df_copy['Order Date'].dt.month]).agg({'Sales': 'sum'}).sort_values(by='Sales', ascending=False)
# Out:
#                              Sales
# Order Date Order Date
# 2017       11          118447.8250
# 2016       12           96999.0430
# 2017       9            87574.6920
#            12           83829.3188
# 2014       9            81777.3508
# 2016       11           79411.9658
# 2014       11           78628.7167
# 2017       10           77776.9232
# 2015       11           75972.5635
#            12           74919.5212
# 2016       9            73410.0249
# 2014       12           69136.8765
# 2015       9            64595.9180
# 2017       8            63120.8880
# 2016       10           59687.7450
# 2017       3            58872.3528
# 2016       5            56987.7280
# 2014       3            55691.0090
# 2017       6            52981.7257
# 2016       3            51715.8750
# 2017       7            45264.4160
#            1            43971.3740
#            5            43852.3662
# 2016       6            40344.5340
#            7            39261.9630
# ...

# %%
# Line chart de CHiffre d'affaire par mois et par ans
monthly = ( df_copy
  .groupby(df_copy['Order Date'].dt.to_period('M'))['Sales']
  .sum()
  .sort_index()
)
monthly.plot(marker='o', figsize=(14, 6))
plt.title("Chiffre d'affaires par mois")
plt.xlabel("Période (Année‑Mois)")
plt.ylabel("Sales (€)")
plt.tight_layout()
plt.show()

# %% [markdown]
# D'après notre graphique, nous constatons une baisse très significative au mois de janvier, qui est précédé un pique au mois de décenbre certainement dû au fêtes de fin d'années.
#
# Les mois de semptembre aussi sont à signaler car c'est une periode de rentrée scolaire, periode où nous remarquons une augmantation des ventes

# %%
# Profits d'affaires par ans
df_copy.groupby(df_copy['Order Date'].dt.year).agg({'Profit': 'sum'}).sort_values(by='Profit', ascending=False)
# Out:
#                 Profit
# Order Date
# 2017        93260.4441
# 2016        81663.7923
# 2015        61618.6037
# 2014        49445.4376

# %%
# Pie plot du Profit par ans
df_copy.groupby(df_copy['Order Date'].dt.year).agg({'Profit': 'sum'}).sort_values(by='Profit', ascending=False).plot(kind='pie', y='Profit', autopct='%1.1f%%')
plt.title('Profit par ans')
plt.ylabel('')
plt.show()

# %%
# Profit mois et par ans
df_copy.groupby([df_copy['Order Date'].dt.year, df_copy['Order Date'].dt.month]).agg({'Profit': 'sum'}).sort_values(by='Profit', ascending=False)
# Out:
#                            Profit
# Order Date Order Date
# 2016       12          17885.3093
#            10          16243.1425
# 2017       3           14751.8915
# 2015       11          12474.7884
# 2017       9           10889.3696
# 2015       3            9732.0978
# 2017       11           9690.1037
# 2016       9            9328.6576
# 2014       11           9292.1269
# 2017       10           9275.2755
#            8            9040.9557
# 2014       12           8906.9304
# 2016       5            8662.1464
# 2017       12           8483.3468
# 2014       9            8328.0994
# 2017       6            8223.3357
# 2015       9            8209.1627
#            12           8016.9659
# 2017       1            7140.4391
#            7            6952.6212
#            5            6265.9433
# 2015       8            5355.8084
# 2014       8            5318.1050
# 2016       2            5004.5795
# 2014       6            4976.5244
# 2016       6            4750.3781
# ...

# %%
# Line chart de Profit par mois et par ans
monthly = ( df_copy
  .groupby(df_copy['Order Date'].dt.to_period('M'))['Profit']
  .sum()
  .sort_index()
)
monthly.plot(marker='o', figsize=(14, 6))
plt.title("Profit par mois")
plt.xlabel("Période (Année‑Mois)")
plt.ylabel("Profit (€)")
plt.tight_layout()
plt.show()

# %% [markdown]
# Parlant du profit aussi, nous constatons que le profit baisse puisque les ventes baissent au mois de Janviers. Bien que que le profit et les ventes n'ont (dans notre dataset) pas une correlation très forte mais il en va de soit qu'il y en a assez pour constater ce lien etre les deux.
#
# On peut donc constater que quand les ventes augmentent, les profits aussi suivent.
#
# Les mois de semptembre aussi sont à signaler car c'est une periode de rentrée scolaire, periode où nous remarquons une augmantation du profit

# %%
# Delais de livraison par regions

# %%
# Delais de livraison par city
# 1. Ajouter une colonne 'Delivery_Days'
df_copy_dates['Delivery_Days'] = (df_copy['Ship Date'] - df_copy['Order Date']).dt.days
# Out:
# /tmp/ipython-input-69-135639676.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy_dates['Delivery_Days'] = (df_copy['Ship Date'] - df_copy['Order Date']).dt.days

# %%
# Moyenne
mean_by_state = df_copy_dates.groupby(df_copy_categs['State'])['Delivery_Days'].mean().sort_values(ascending=False)

# Médiane (plus robuste aux outliers)
median_by_state = df_copy_dates.groupby(df_copy_categs['State'])['Delivery_Days'].median().sort_values(ascending=False)

# %%
# Moyenne de jours de livraison arrondi
mean_by_state.round()
# Out:
# State
# District of Columbia    6.0
# Wyoming                 5.0
# Maine                   5.0
# Montana                 5.0
# New Mexico              5.0
# Minnesota               4.0
# Oklahoma                4.0
# New Jersey              4.0
# South Dakota            4.0
# Nevada                  4.0
# Tennessee               4.0
# Iowa                    4.0
# Utah                    4.0
# Indiana                 4.0
# Oregon                  4.0
# Delaware                4.0
# Mississippi             4.0
# Arkansas                4.0
# Illinois                4.0
# Alabama                 4.0
# Michigan                4.0
# Missouri                4.0
# Arizona                 4.0
# New York                4.0
# Maryland                4.0
# Wisconsin               4.0
# North Carolina          4.0
# Washington              4.0
# Kansas                  4.0
# Florida                 4.0
# Texas                   4.0
# Vermont                 4.0
# Pennsylvania            4.0
# ...

# %%
# Median de jours de livraison arrondi
median_by_state.round()
# Out:
# State
# District of Columbia    6.0
# Indiana                 5.0
# Delaware                5.0
# South Dakota            5.0
# Utah                    5.0
# Wyoming                 5.0
# New Mexico              5.0
# Montana                 5.0
# Maine                   5.0
# Oklahoma                5.0
# Oregon                  5.0
# Iowa                    4.0
# Alabama                 4.0
# Colorado                4.0
# California              4.0
# Arizona                 4.0
# Arkansas                4.0
# Virginia                4.0
# Kentucky                4.0
# Kansas                  4.0
# Illinois                4.0
# Georgia                 4.0
# Idaho                   4.0
# Connecticut             4.0
# Florida                 4.0
# Missouri                4.0
# Nebraska                4.0
# New Hampshire           4.0
# Massachusetts           4.0
# Michigan                4.0
# Minnesota               4.0
# Mississippi             4.0
# Maryland                4.0
# ...

# %%
# Bar chart des moyennes de jours de livraisons
plt.figure(figsize=(14, 6))
mean_by_state.plot(kind='bar', color='skyblue')
# Out:
# <Axes: xlabel='State'>

# %%
# Nombre d'état par delais moyen de livraison (arrondi)
mean_by_state.round().value_counts()
# Out:
# Delivery_Days
# 4.0    39
# 3.0     5
# 5.0     4
# 6.0     1
# Name: count, dtype: int64

# %%
# L'état le plus rapdie en livraison
print(f"L'état le plus rapide est :  {mean_by_state.idxmin()}, avec {round(mean_by_state.min())} jours")
# Out:
# L'état le plus rapide est :  North Dakota, avec 3 jours

# %%
# L'état le plus rapdie en livraison
print(f"L'état le plus lent est :  {mean_by_state.idxmax()}, avec {round(mean_by_state.max())} jours")
# Out:
# L'état le plus lent est :  District of Columbia, avec 6 jours

# %%
# Dashboard de recapitulatif
# Pré-calcul des métriques
total_sales      = df_copy_nums['Sales'].sum().round(2)
total_profit     = df_copy_nums['Profit'].sum().round(2)
n_orders         = df_copy_categs['Order ID'].nunique()
avg_basket       = (total_sales / n_orders).round(2)
pct_profitable   = (df_copy.groupby('Order ID')['Profit']
                       .sum().gt(0).mean() * 100).round(1)
avg_discount     = (df_copy_nums['Discount'].mean()).round(1)
avg_delivery     = df_copy_dates['Delivery_Days'].mean().round(1)

#Construction du mini-dashboard
dashboard = pd.DataFrame({
    'KPI': [
        "CA total (€)",
        "Profit total (€)",
        "Nb commandes",
        "Panier moyen (€)",
        "% commandes rentables",
        "Remise moyenne (%)",
        "Délai moyenne (jours)"
    ],
    'Valeur': [
        total_sales,
        total_profit,
        n_orders,
        avg_basket,
        pct_profitable,
        avg_discount,
        avg_delivery
    ]
})

# 3. Affichage
dashboard.style.set_properties(subset=['Valeur'], **{'font-weight': 'bold'})
# Out:
# <style type="text/css">
# #T_46742_row0_col1, #T_46742_row1_col1, #T_46742_row2_col1, #T_46742_row3_col1, #T_46742_row4_col1, #T_46742_row5_col1, #T_46742_row6_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_46742" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46742_level0_col0" class="col_heading level0 col0" >KPI</th>
#       <th id="T_46742_level0_col1" class="col_heading level0 col1" >Valeur</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46742_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46742_row0_col0" class="data row0 col0" >CA total (€)</td>
#       <td id="T_46742_row0_col1" class="data row0 col1" >2295273.920000</td>
#     </tr>
#     <tr>
#       <th id="T_46742_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46742_row1_col0" class="data row1 col0" >Profit total (€)</td>
# ...

# %% [markdown]
# # Carte Géographique

# %%
# Codage des abreviation des etats
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
# Mappage des noms d'États en abbréviations
df_copy['state_abbrev'] = df_copy['State'].map(us_state_abbrev)

# agrégation du profit par abréviation
state_profit = (
    df_copy
    .groupby('state_abbrev')['Profit']
    .sum()
    .reset_index()
    .rename(columns={'Profit': 'Total_Profit'})
)

# %%
# Creation de la carte
import plotly.express as px

fig = px.choropleth(
    state_profit,
    locations='state_abbrev',          # abréviations, ex. "CA", "NY"
    locationmode='USA-states',         # carte US
    color='Total_Profit',              # variable à colorer
    scope='usa',                       # restreint aux USA
    color_continuous_scale='Viridis',  # palette (optionnel)
    labels={'Total_Profit': 'Profit (€)'},
    title='Profit total par État'
)
fig.update_layout(margin=dict(l=0, r=0, t=50, b=0))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
